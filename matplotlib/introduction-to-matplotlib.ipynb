# %% [markdown]
# ## Introduction to Matplotlib

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();
#to get rid the '[]' in the output

# %%
plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4]);

# %%
#stateless of plotting
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y);

# %%
#1st method
fig = plt.figure() #create a figure
ax = fig.add_subplot() #adds some axes
plt.show()

# %%
#2nd method
fig = plt.figure() #creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x , y) #add some data
plt.show()

# %%
#3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250]); #add some data

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10, 10)) # (width, height of the plot)

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Simple Plot",
      xlabel = "x-axis",
      ylabel = "y-axis")

# 5. Save & show (you save the whole figure)
fig.savefig("./sample-plot.png")

# %% [markdown]
# ## Making figures with NumPy arrays
#
# We want:
# * Line Plot
# * Scatter Plot
# * Bar Plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# Create some data
x = np.linspace(0, 10, 100) #between 0, 10, with 100 as size.
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# Plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Use the same data to make scatter
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a plot from dictionary

#prepare the data
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}
nut_butter_prices
# Out:
# {'Almond butter': 10, 'Peanut butter': 8, 'Cashew butter': 12}

# %%
fig, ax = plt.subplots()
x = nut_butter_prices.keys()
y = nut_butter_prices.values()
store_name = "Dan's Butter"
y_axis_label = "Price ($)"
ax.bar(x,y);

# I can use f string here
ax.set(title = f"{store_name} Store",
       ylabel=y_axis_label);

# %%
#https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.barh.html
#check the documentation for the bar graph

fig, ax = plt.subplots()
ax.set(title="Dan's Butter Store", xlabel="Prices ($)")
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()), color='orange', align='center');

# %%
#Make some data for histograms and plot it
x = np.random.randn(1000)

fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # Two Options for Subplots

# %%
# Subplots option 1 (recommended)
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10, 5))

# Plot to each different axis
ax1.plot(x , x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# Subplots option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10, 5));

# Plot to each different index
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# # Plotting from pandas DataFrames

# %%
import pandas as pd

# %%
# Make a dataframe
car_sales = pd.read_csv("../pandas/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# example
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range("03/22/2023", periods=1000));
ts = ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales
# Out:
# C:\Users\canci\AppData\Local\Temp\ipykernel_16140\2276578600.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range('03/22/2023', periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2023-03-22
# 1   Honda    Red          87899      4   5000 2023-03-23
# 2  Toyota   Blue          32549      3   7000 2023-03-24
# 3     BMW  Black          11179      5  22000 2023-03-25
# 4  Nissan  White         213095      4   3500 2023-03-26
# 5  Toyota  Green          99213      4   4500 2023-03-27
# 6   Honda   Blue          45698      4   7500 2023-03-28
# 7   Honda   Blue          54738      4   7000 2023-03-29
# 8  Toyota  White          60000      4   6250 2023-03-30
# 9  Nissan  White          31600      4   9700 2023-03-31

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum() #astype(int) converting to int data type

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-03-22         4000
# 1   Honda    Red          87899      4   5000 2023-03-23         9000
# 2  Toyota   Blue          32549      3   7000 2023-03-24        16000
# 3     BMW  Black          11179      5  22000 2023-03-25        38000
# 4  Nissan  White         213095      4   3500 2023-03-26        41500
# 5  Toyota  Green          99213      4   4500 2023-03-27        46000
# 6   Honda   Blue          45698      4   7500 2023-03-28        53500
# 7   Honda   Blue          54738      4   7000 2023-03-29        60500
# 8  Toyota  White          60000      4   6250 2023-03-30        66750
# 9  Nissan  White          31600      4   9700 2023-03-31        76450

# %%
# Plot the total sales
car_sales.plot(x = "Sale Date", y="Total Sales"); # default is line graph

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter"); #use the 'kind' props to change the chart

# %%
# Bar graph
x = np.random.rand(10, 4)
x

# turn it in a dataframe
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.228723  0.576654  0.737842  0.050486
# 1  0.988917  0.268040  0.163627  0.304906
# 2  0.813800  0.044716  0.174056  0.095672
# 3  0.777359  0.135408  0.635650  0.326874
# 4  0.465865  0.974296  0.706788  0.190602
# 5  0.127168  0.741642  0.033024  0.946850
# 6  0.954429  0.521903  0.313894  0.781836
# 7  0.996372  0.266601  0.184344  0.873389
# 8  0.713921  0.424691  0.545050  0.097118
# 9  0.596394  0.370393  0.989255  0.377056

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot(kind='bar') #using the props 'kind'
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-03-22         4000
# 1   Honda    Red          87899      4   5000 2023-03-23         9000
# 2  Toyota   Blue          32549      3   7000 2023-03-24        16000
# 3     BMW  Black          11179      5  22000 2023-03-25        38000
# 4  Nissan  White         213095      4   3500 2023-03-26        41500
# 5  Toyota  Green          99213      4   4500 2023-03-27        46000
# 6   Honda   Blue          45698      4   7500 2023-03-28        53500
# 7   Honda   Blue          54738      4   7000 2023-03-29        60500
# 8  Toyota  White          60000      4   6250 2023-03-30        66750
# 9  Nissan  White          31600      4   9700 2023-03-31        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
# Histogram

car_sales["Odometer (KM)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#using the 'key' props

car_sales["Odometer (KM)"].plot(kind="hist");

# %%
# Trying another dataset

heart_disease = pd.read_csv('../data_set/heart-disease.csv')
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# create histogram
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %%
# Which one should you use?
# When plotting something quickly, okay to use the pyplot method
# When plotting something moe advance, use the OO method (what is OO method, by the way? hahaha)

heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# creating another dataframe to focus on the age greater than 50

over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# len(over_50) # return 208
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot method, diretly plotting from the dataframe

over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            figsize=(10, 6));

# %%
# OO method mixed eith pyplot method
# (OO - object Oriented)

fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            ax=ax);

ax.set_xlim([45, 100]) # setting the limit of axis
# Out:
# (45.0, 100.0)

# %%
# OO method from scratch
fig, ax = plt.subplots(figsize=(10, 6)) # creating the figures and axis

# Plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"]);

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
      xlabel="Age",
      ylabel="Cholesterol");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# subplot of chol, age, thalach

fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10, 10),
                              sharex=True);

# add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"]);

# customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol");

# add legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

# add a meanline
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--")

# add data to ax1
scatter1 = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"]);

# customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
        xlabel="Age",
        ylabel="Max Heart Rate");

# add legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target")

# add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--");

# add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")

# %% [markdown]
# # Customizing Matplotlib plots

# %%
# see the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
# cahnging the default style of the graph
plt.style.use("seaborn-v0_8")
plt.style.use("seaborn-v0_8-whitegrid")

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
plt.style.use("ggplot")
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
# create some data
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.32980051,  0.2820516 ,  0.25340084,  1.04101155],
#        [-0.52891577,  2.14791807,  0.69315104,  0.82572701],
#        [-1.26934504,  0.27227233,  1.54738071, -0.75511844],
#        [-0.24441942,  0.47679238, -0.44224639, -0.66759381],
#        [-1.17116592,  0.66943325,  1.82632844, -0.29893063],
#        [ 1.07228624,  0.81627454,  0.75799422,  1.05570408],
#        [-0.81143036, -0.49289344, -0.36761865, -0.34351907],
#        [-2.12193241,  1.69761298, -0.20511726,  1.63138918],
#        [-0.71000605,  0.4023761 , -0.38399767,  1.71112722],
#        [-0.81083449, -1.58682026,  1.94815544, -0.28676659]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.329801  0.282052  0.253401  1.041012
# 1 -0.528916  2.147918  0.693151  0.825727
# 2 -1.269345  0.272272  1.547381 -0.755118
# 3 -0.244419  0.476792 -0.442246 -0.667594
# 4 -1.171166  0.669433  1.826328 -0.298931
# 5  1.072286  0.816275  0.757994  1.055704
# 6 -0.811430 -0.492893 -0.367619 -0.343519
# 7 -2.121932  1.697613 -0.205117  1.631389
# 8 -0.710006  0.402376 -0.383998  1.711127
# 9 -0.810834 -1.586820  1.948155 -0.286767

# %%
ax = df.plot(kind="bar")
type(ax);

# %%
# Customize the plot with the set() method
ax = df.plot(kind="bar")
ax.set(title="Random Number Bar Graph from the DataFrame",
      xlabel="Row Number",
      ylabel="Random Number");

# make the legend visible
ax.legend().set_visible(True)

# %%
# set the style
plt.style.use('seaborn-v0_8-whitegrid')

# OO method from scratch
fig, ax = plt.subplots(figsize=(10, 6)) # creating the figures and axis

# Plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"],
                    cmap="winter"); #this will change the color scheme

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
      xlabel="Age",
      ylabel="Cholesterol");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %%
# customizing the y and x axis limitations



# subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10, 10),
                              sharex=True);

# add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"],
                      cmap="winter");

# customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol",
        xlim=([50,80]));

# add legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

# add a meanline
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--",
            color="red")

# add data to ax1
scatter1 = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"],
                      cmap="winter");

# customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
        xlabel="Age",
        ylabel="Max Heart Rate",
        ylim=([60,220]));

# add legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target")

# add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--",
            color="red");

# add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')
